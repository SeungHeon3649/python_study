# %%
# 1. 실수형 값 7.5와 2.5에 대해 연산자를 모두 사용하여 프로그래밍

x = 7.5
y = 2.5

print(f""">>>
{x + y}
>>>
{x - y}
>>>
{x * y}
>>>
{x / y}
>>>
{x // y}
>>>
{x % y}
""")
# Out:
# >>>
# 10.0
# >>>
# 5.0
# >>>
# 18.75
# >>>
# 3.0
# >>>
# 3.0
# >>>
# 0.0

# %%
# 2.

num = 3.5
print(type(num))
# Out:
# <class 'float'>

# %%
# 3.

name = "홍길동"
print(type(name))
# Out:
# <class 'str'>

# %%
# 4.

#(1) var
#(2) 문자열형
#(3) str
# Out:
# str

# %%
# 5.

# a == 7
# 3 <= b
# True
# True

# %%
# 6.

pi = 3.14
r = 2
print(pi*(r**2))
# Out:
# 12.56
